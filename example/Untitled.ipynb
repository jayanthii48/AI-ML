# %%
import pandas as pd

# %%
sam=pd.read_csv('sale.csv')

# %%
sam
# Out:
#   Month  Sales  Revenue   Customers  Avg Purchase
# 0   Jan   1200     30000       4500          25.00
# 1   Feb   1500     35000       5000          23.30
# 2   Mar   1700     40000       5500          23.50
# 3   Apr   1600     38000       5200          23.75
# 4   May   1800     42000       5700          23.30

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(sam['Sales'],labels=sam['Month'], colors=['red','yellow','green','blue','black'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x275a4ca2950>,
# ...
#  [Text(0.9740016190143815, 0.5111955067851864, 'Jan'),
#   Text(-5.149471629032507e-08, 1.0999999999999988, 'Feb'),
#   Text(-1.0565699422641652, 0.30603914309104097, 'Mar'),
#   Text(-0.5499999256737775, -0.9526279870751434, 'Apr'),
#   Text(0.8233618886561177, -0.7294348499411245, 'May')],
#  [Text(0.5312736103714808, 0.2788339127919199, '15.4%'),
#   Text(-2.8088027067450036e-08, 0.5999999999999993, '19.2%'),
#   Text(-0.5763108775986355, 0.1669304416860223, '21.8%'),
#   Text(-0.29999995945842406, -0.5196152656773508, '20.5%'),
#   Text(0.4491064847215187, -0.3978735545133406, '23.1%')])

# %%
x=sam['Customers']

# %%
y=sam['Month']

# %%
plt.fill_between(x, y, color='red', alpha=0.5)
