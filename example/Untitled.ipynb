# %%
import pandas as pd

# %%
sale = pd.read_csv('Online Sales Data.csv')

# %%
sale
# Out:
#     Transaction ID        Date Product category  \
# 0            10001  2024-01-01      Electronics
# 1            10002  2024-01-02  Home Appliances
# 2            10003  2024-01-03         Clothing
# 3            10004  2024-01-04              NaN
# 4            10005  2024-01-05  Beauty Products
# 5            10006  2024-01-06           Sports
# 6            10007  2024-01-07      Electronics
# 7            10008  2024-01-08  Home Appliances
# 8            10009  2024-01-09         Clothing
# 9            10010  2024-01-10            Books
# 10           10011  2024-01-11  Beauty Products
# 11           10012  2024-01-12           Sports
# 12           10013  2024-01-13      Electronics
# 13           10014  2024-01-14  Home Appliances
# 14           10015  2024-01-15         Clothing
# 15           10016  2024-01-16            Books
# 16           10017  2024-01-17  Beauty Products
# 17           10017  2024-01-17  Beauty Products
# ...

# %%
sale.isnull()
# Out:
#     Transaction ID   Date  Product category  Product Name  Units Sold  \
# 0            False  False             False         False        True
# 1            False  False             False         False       False
# 2            False  False             False         False       False
# 3            False  False              True         False       False
# 4            False  False             False         False       False
# 5            False  False             False         False       False
# 6            False  False             False         False       False
# 7            False  False             False         False       False
# 8            False  False             False         False       False
# 9            False  False             False         False       False
# 10           False  False             False         False       False
# 11           False  False             False         False       False
# ...

# %%
sale.notnull()
# Out:
#     Transaction ID  Date  Product category  Product Name  Units Sold  \
# 0             True  True              True          True       False
# 1             True  True              True          True        True
# 2             True  True              True          True        True
# 3             True  True             False          True        True
# 4             True  True              True          True        True
# 5             True  True              True          True        True
# 6             True  True              True          True        True
# 7             True  True              True          True        True
# 8             True  True              True          True        True
# 9             True  True              True          True        True
# 10            True  True              True          True        True
# 11            True  True              True          True        True
# 12            True  True              True          True        True
# ...

# %%
sale.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product category    2
# Product Name        1
# Units Sold          2
# Unit Price          2
# Total Revenue       2
# Region              3
# Payment Method      3
# dtype: int64

# %%
sale.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    53 non-null     int64
#  1   Date              53 non-null     object
#  2   Product category  51 non-null     object
#  3   Product Name      52 non-null     object
#  4   Units Sold        51 non-null     float64
#  5   Unit Price        51 non-null     float64
#  6   Total Revenue     51 non-null     float64
#  7   Region            50 non-null     object
#  8   Payment Method    50 non-null     object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.9+ KB

# %%
sale['Product category'].value_counts(dropna= False)
# Out:
# Product category
# Electronics        9
# Clothing           9
# Beauty Products    9
# Home Appliances    8
# Sports             8
# Books              8
# Name: count, dtype: int64

# %%
sale.head()
# Out:
#    Transaction ID        Date Product category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04              NaN        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0         NaN      999.99        1999.98  North America    Credit Card
# 1         1.0      499.99         499.99         Europe         PayPal
# 2         3.0       69.99         209.97           Asia     Debit Card
# 3         4.0       15.99          63.96  North America    Credit Card
# 4         1.0       89.99          89.99         Europe         PayPal

# %%
sale.tail()
# Out:
#     Transaction ID        Date Product category                Product Name  \
# 48           10047  2024-02-16  Beauty Products     Clinique Moisture Surge
# 49           10048  2024-02-17           Sports        Yeti Rambler Tumbler
# 50           10049  2024-02-18      Electronics           Kindle Paperwhite
# 51           10050  2024-01-22            Books  Gone Girl by Gillian Flynn
# 52           10051  2024-02-12           Sports                         NaN
#
#     Units Sold  Unit Price  Total Revenue         Region Payment Method
# 48         1.0       52.00          52.00         Europe         PayPal
# 49         6.0       39.99         239.94           Asia    Credit Card
# 50         2.0      129.99         259.98  North America    Credit Card
# 51         2.0       22.99          45.98           Asia    Credit Card
# 52         NaN         NaN            NaN            NaN            NaN

# %%
sale[sale.isnull().any(axis=1)]
# Out:
#     Transaction ID        Date Product category              Product Name  \
# 0            10001  2024-01-01      Electronics             iPhone 14 Pro
# 3            10004  2024-01-04              NaN         The Da Vinci Code
# 6            10007  2024-01-07      Electronics       MacBook Pro 16-inch
# 21           10021  2024-01-21         Clothing         Zara Summer Dress
# 31           10030  2024-01-30              NaN  Nike Air Zoom Pegasus 37
# 37           10036  2024-02-05           Sports              Peloton Bike
# 38           10037  2024-02-06      Electronics      Apple Watch Series 8
# 45           10044  2024-02-13  Home Appliances      Nespresso VertuoPlus
# 52           10051  2024-02-12           Sports                       NaN
#
#     Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0          NaN      999.99        1999.98  North America    Credit Card
# 3          4.0       15.99          63.96  North America    Credit Card
# ...

# %%
sale.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product category    2
# Product Name        1
# Units Sold          2
# Unit Price          2
# Total Revenue       2
# Region              3
# Payment Method      3
# dtype: int64

# %%
mean ==average ,,,mode= repeated values ,median ,ffill ,bfill

numerical ,categorical

# %%
sale1=sale.dropna()

# %%
sale1.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product category    0
# Product Name        0
# Units Sold          0
# Unit Price          0
# Total Revenue       0
# Region              0
# Payment Method      0
# dtype: int64

# %%
sale1.shape
# Out:
# (44, 9)

# %%
sale2=sale.dropna(axis=1)

# %%
sale2.isnull().sum()
# Out:
# Transaction ID    0
# Date              0
# dtype: int64

# %%
sale.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product category    2
# Product Name        1
# Units Sold          2
# Unit Price          2
# Total Revenue       2
# Region              3
# Payment Method      3
# dtype: int64

# %%
sale3=sale['Unit Price'].fillna(0)

# %%
sale3
# Out:
# 0      999.99
# 1      499.99
# 2       69.99
# 3       15.99
# 4       89.99
# 5       29.99
# 6        0.00
# 7      599.99
# 8       89.99
# 9       25.99
# 10     129.99
# 11     199.99
# 12     749.99
# 13     189.99
# 14     249.99
# 15      35.99
# 16     399.99
# 17     399.99
# 18     119.99
# 19     499.99
# 20      99.99
# 21      59.99
# 22      59.99
# 23      22.99
# 24      49.99
# 25      29.99
# 26     299.99
# 27     179.99
# 28     179.99
# 29      12.99
# 30      29.99
# 31     129.99
# 32     349.99
# 33      89.99
# 34      29.99
# 35      19.99
# 36      39.99
# 37    1895.00
# 38     399.99
# 39     799.99
# 40      59.99
# 41      24.99
# 42     105.00
# 43     129.99
# 44     399.99
# 45     199.99
# 46     139.99
# 47      32.50
# 48      52.00
# 49      39.99
# 50     129.99
# 51      22.99
# 52       0.00
# Name: Unit Price, dtype: float64

# %%
sale.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product category    2
# Product Name        1
# Units Sold          2
# Unit Price          2
# Total Revenue       2
# Region              3
# Payment Method      3
# dtype: int64

# %%
sale['Unit Price']=sale['Unit Price'].fillna(0)

# %%
sale.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Product category    2
# Product Name        1
# Units Sold          2
# Unit Price          0
# Total Revenue       2
# Region              3
# Payment Method      3
# dtype: int64
